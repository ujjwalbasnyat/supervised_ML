# %% [markdown]
# <a href="https://colab.research.google.com/github/ujjwalbasnyat/supervised_ML/blob/MSE%2C-RMSE%2C-R2_SCORE/Iris.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from sklearn.datasets import load_iris
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
iris = load_iris()

# %%
dir(iris)
# Out:
# ['DESCR',
#  'data',
#  'data_module',
#  'feature_names',
#  'filename',
#  'frame',
#  'target',
#  'target_names']

# %%
iris.data[0]
# Out:
# array([5.1, 3.5, 1.4, 0.2])

# %%
# scatter plot
plt.scatter(iris.data[:,0], iris.data[:,1], c=iris.target)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(iris.data, iris.target, test_size=0.2)

# %%
#choose the logistic regression model
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()

# %%
#train the model
model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
#predicting the model with test data
model.predict(X_test)
# Out:
# array([0, 2, 0, 1, 1, 1, 1, 2, 1, 2, 0, 1, 2, 0, 2, 1, 0, 2, 0, 1, 0, 1,
#        0, 2, 2, 0, 0, 1, 2, 2])

# %%
len(X_test)
# Out:
# 30

# %%
#test accuracy
model.score(X_test, y_test)
# Out:
# 0.9666666666666667

# %%
from sklearn.metrics import confusion_matrix

# %%
#compute the confusion matrix
y_predicted = model.predict(X_test)

# %%
cm = confusion_matrix(y_test, y_predicted)

# %%
#Visualize the confusion matrix
sns.heatmap(cm, annot=True)
plt.xlabel('Predicted')
plt.ylabel('Truth')
plt.title('Confusion Matrix')
plt.show()
