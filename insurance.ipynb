# %%
import pandas as pd
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
df= pd.read_csv('insurance_data.csv')
df.head()
# Out:
#    age  bought_insurance
# 0   22                 0
# 1   25                 0
# 2   47                 1
# 3   52                 0
# 4   46                 1

# %%
plt.scatter(df['age'], df['bought_insurance'], marker="x", color='red')

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(df[['age']], df['bought_insurance'], test_size=0.1)

# %%
from sklearn.linear_model import LogisticRegression

# %%
model = LogisticRegression()

# %%
X_test
# Out:
#     age
# 20   21
# 23   45
# 12   27

# %%
model.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
model.predict(X_test)
# Out:
# array([0, 1, 0])

# %%
y_test
# Out:
# 20    0
# 23    1
# 12    0
# Name: bought_insurance, dtype: int64

# %%
model.score(X_test, y_test)
# Out:
# 1.0

# %%
model.predict_proba(X_test)
# Out:
# array([[0.90365545, 0.09634455],
#        [0.31742353, 0.68257647],
#        [0.81569952, 0.18430048]])

# %%
model.predict([[19]])
# Out:
# c:\Users\uzoli\per_capita_prediction\per_capita_venv\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([0])
